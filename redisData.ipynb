# %%
import redis
from flask import Flask, request, jsonify
import requests
import random

redis_client = redis.Redis(host='host', port=port, db=0)

# %%
url_train = f"http://host/v1/machine"
response_train = requests.get(url_train)
testData = response_train.json()

# %%
for  value in testData:
    print(value['automationId'])
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 16
# None
# 5
# None
# None
# 14
# 21
# None
# None
# 13
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 6
# 7
# None
# 11
# 12
# 4
# 18
# 2
# 17
# 22
# 19
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 1
# 8
# 9
# 10
# 3
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 23
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
 redisField = ['fabricWeight',
    'netFabricWeight',
    'runningStartTime',
    'runningFinishTime',
    'runningJobOrderNumber',
    'runningItemOrderDetail',
    'runningItemName',
    'runningColorName',
    'mq_part_start',
    'mq_part_end',
    'runningBatchStatus',
    'mq_part_no',
    'mq_part_count',
    'mq_order_counter',
    'm_electricity_counter',
    'm_water_counter',
    'm_natural_counter',
    'm_steam_counter',
    'mq_th_duration',
    'mq_part_duration',
    'mq_calc_duration']

# %%
for value in testData:
    current_temperature = random.randint(0, 200)  
    redis_client.hset(f"machine:{value['id']}", 'currentTemperature', current_temperature)
    redis_client.hset(f"machine:{value['id']}", 'id', value['id'])
    
    if value['automationId']:
        redis_client.hset(f"machine:{value['id']}", 'automationId', value['automationId'])
    else:
        redis_client.hset(f"machine:{value['id']}", 'automationId', '')
    
    redis_client.hset(f"machine:{value['id']}", 'runningJobOrder', '')
    summary_start_state = {"electricity": 0, "water": 0, "steam": 0, "naturalGas": 0}
    redis_client.hset(f"machine:{value['id']}", 'summary_start_state', json.dumps(summary_start_state))
    for field in redisField:
        redis_client.hset(f"machine:{value['id']}", field, '')
